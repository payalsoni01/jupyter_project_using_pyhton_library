# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# Load dataset
df = pd.read_csv("submission.csv")

# Display first 5 rows
df.head()
# Out:
#        id  diagnosed_diabetes
# 0  700000            0.459341
# 1  700001            0.635013
# 2  700002            0.743871
# 3  700003            0.402927
# 4  700004            0.870859

# %%
# Dataset structure
df.info()

# Shape of dataset
df.shape
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300000 entries, 0 to 299999
# Data columns (total 2 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   id                  300000 non-null  int64
#  1   diagnosed_diabetes  300000 non-null  float64
# dtypes: float64(1), int64(1)
# memory usage: 4.6 MB
# (300000, 2)

# %%
# Check null values
df.isnull().sum()
# Out:
# id                    0
# diagnosed_diabetes    0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
# Check if ID is unique
df['id'].is_unique
# Out:
# True

# %%
df.describe()
# Out:
#                   id  diagnosed_diabetes
# count  300000.000000       300000.000000
# mean   849999.500000            0.607653
# std     86602.684716            0.183191
# min    700000.000000            0.060045
# 25%    774999.750000            0.473257
# 50%    849999.500000            0.603016
# 75%    924999.250000            0.740776
# max    999999.000000            1.004862

# %%
df = df[(df['diagnosed_diabetes'] >= 0) & (df['diagnosed_diabetes'] <= 1)]

# %%
plt.figure(figsize=(6,4))
plt.boxplot(df['diagnosed_diabetes'])
plt.title("Outlier Detection for Diagnosed Diabetes")
plt.ylabel("Probability")
plt.show()
